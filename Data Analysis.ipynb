# %%
import pandas as pd

# %% [markdown]
# Missing Days

# %%
# holidays per market per year D/M/Y
# market closes at 13:00 local time on half days - check how this is registered in data

# 2010-2011 https://www.streetinsider.com/Insiders+Blog/NYSE+Releases+2010+and+2011+Holiday+Calendar/4915576.html
# 2012-2019 https://www.marketwatch.com/optionscenter/calendar/2012
# 2020-2021 https://www.dailyfx.com/education/understanding-the-stock-market/stock-market-holidays.html

US = {"2010": ["01/01/2010",  # New Year's day
            "18/01/2010", # Martin Luther King Jr. day
            "15/02/2010", # President's day
            "02/04/2010", # Good Friday
            "31/05/2010", # Memorial day
            "05/07/2010", # Independence day
            "06/09/2010", # Labor day
            "25/11/2010", # Thanksgiving
            "26/11/2010", # half day for Thanksgiving
            "24/12/2010"], # Christmas
    "2011": ["01/01/2011",  # New Year's day
            "17/01/2011", # Martin Luther King Jr. day
            "21/02/2011", # President's' day
            "22/04/2011", # Good Friday
            "30/05/2011", # Memorial day
            "04/07/2011", # Independence day
            "05/09/2011", # Labor day
            "24/11/2011", # Thanksgiving
            "25/11/2011", # half day for Thanksgiving
            "26/12/2011"], # half day for Christmas
    # seems to exclude half days
    "2012": ["01/01/2012",  # New Year's day
            "16/01/2012", # Martin Luther King Jr. day
            "20/02/2012", # President's day
            "06/04/2012", # Good Friday
            "28/05/2012", # Memorial day
            "04/07/2012", # Independence day
            "03/09/2012", # Labor day
            "22/11/2012", # Thanksgiving
#             "26/11/2012", # half day for Thanksgiving
            "25/12/2012"], # Christmas
    # seems to exclude half days
    "2013": ["01/01/2013",  # New Year's day
            "21/01/2013", # Martin Luther King Jr. day
            "18/02/2013", # President's' day
            "29/03/2013", # Good Friday
            "27/05/2013", # Memorial day
            "04/07/2013", # Independence day
            "02/09/2013", # Labor day
            "28/11/2013", # Thanksgiving
#             "25/11/2013", # half day for Thanksgiving
            "25/12/2013"], # half day for Christmas
    # seems to exclude half days
    "2014": ["01/01/2014",  # New Year's day
            "20/01/2014", # Martin Luther King Jr. day
            "17/02/2014", # President's day
            "18/04/2014", # Good Friday
            "26/05/2014", # Memorial day
            "04/07/2014", # Independence day
            "01/09/2014", # Labor day
            "27/11/2014", # Thanksgiving
#             "26/11/2014", # half day for Thanksgiving
            "25/12/2014"], # Christmas
    # seems to exclude half days
    "2015": ["01/01/2015",  # New Year's day
            "19/01/2015", # Martin Luther King Jr. day
            "16/02/2015", # President's' day
            "03/04/2015", # Good Friday
            "25/05/2015", # Memorial day
            "03/07/2015", # Independence day
            "07/09/2015", # Labor day
            "26/11/2015", # Thanksgiving
#             "25/11/2015", # half day for Thanksgiving
            "25/12/2015"], # half day for Christmas
    # seems to exclude half days
    "2016": ["01/01/2016",  # New Year's day
            "18/01/2016", # Martin Luther King Jr. day
            "15/02/2016", # President's day
            "25/03/2016", # Good Friday
            "30/05/2016", # Memorial day
            "04/07/2016", # Independence day
            "05/09/2016", # Labor day
            "24/11/2016", # Thanksgiving
#             "26/11/2016", # half day for Thanksgiving
            "26/12/2016"], # Christmas
    # seems to exclude half days
    "2017": ["01/01/2017",  # New Year's day
            "16/01/2017", # Martin Luther King Jr. day
            "20/02/2017", # President's' day
            "14/04/2017", # Good Friday
            "29/05/2017", # Memorial day
            "04/07/2017", # Independence day
            "04/09/2017", # Labor day
            "23/11/2017", # Thanksgiving
#             "25/11/2017", # half day for Thanksgiving
            "25/12/2017"], # half day for Christmas
    # seems to exclude half days
    "2018": ["01/01/2018",  # New Year's day
            "15/01/2018", # Martin Luther King Jr. day
            "19/02/2018", # President's day
            "30/03/2018", # Good Friday
            "28/05/2018", # Memorial day
            "04/07/2018", # Independence day
            "03/09/2018", # Labor day
            "22/11/2018", # Thanksgiving
#             "26/11/2018", # half day for Thanksgiving
            "25/12/2018"], # Christmas
    # seems to exclude half days
    "2019": ["01/01/2019",  # New Year's day
            "21/01/2019", # Martin Luther King Jr. day
            "18/02/2019", # President's' day
            "19/04/2019", # Good Friday
            "27/05/2019", # Memorial day
            "04/07/2019", # Independence day
            "02/09/2019", # Labor day
            "28/11/2019", # Thanksgiving
#             "25/11/2019", # half day for Thanksgiving
            "25/12/2019"], # half day for Christmas
    "2020": ["01/01/2020",  # New Year's day
           "20/01/2020", # Martin Luther King Jr. day
           "17/02/2020", # President's day
           "10/04/2020", # Good Friday
           "25/05/2020", # Memorial day
           "03/07/2020", # Independence day
           "07/09/2020", # Labor day
           "26/11/2020", # half day for Thanksgiving
           "25/12/2020"], # half day for Christmas
    "2021": ["01/01/2021", # New Year's day
           "18/01/2021", # Martin Luther King Jr. day
           "15/02/2021", # President's day
           "02/04/2021", # Good Friday
           "31/05/2021", # Memorial day
           "05/07/2021", # Independence day
           "06/09/2021", # Labor day
           "25/11/2021", # half day for Thanksgiving
           "24/12/2021"] # Christmas
} # impacts SP500, NASDAQ, US30 and US2000


# 2020-2021 https://www.dailyfx.com/education/understanding-the-stock-market/stock-market-holidays.html
UK = {"2020": ["01/01/2020", # New Year's day
            "10/04/2020", # Good Friday
            "13/04/2020", # Easter Monday
            "08/05/2020", # Early May bank holiday
            "25/05/2020", # Early May bank holiday
            "31/08/2020", # Summer bank holiday
            "24/12/2020", # half day for Christmas eve
            "25/12/2020", # Christmas
            "28/12/2020", # Boxing day
            "31/12/2020"], # half day for New Year's Eve
    "2021": ["01/01/2021", # New Year's day
            "02/04/2021", # Good Friday
            "05/04/2021", # Easter Monday
            "03/05/2021", # Early May bank holiday
            "31/05/2021", # Early May bank holiday
            "30/08/2021", # Summer bank holiday
            "24/12/2021", # half day for Christmas eve
            "27/12/2021", # Christmas
            "28/12/2021", # Boxing day
            "31/12/2021"] # half day for New Year's Eve
} # impacts UK100


# 2020-2021 https://www.dailyfx.com/education/understanding-the-stock-market/stock-market-holidays.html
GER = {"2020": ["01/01/2020", # New Year's day
            "10/04/2020", # Good Friday
            "13/04/2020", # Easter Monday
            "01/05/2020", # Labor day
            "01/06/2020", # White Monday
            "03/10/2020", # Day of German Unity
            "24/12/2020", # Christmas eve
            "25/12/2020", # Christmas
            "26/12/2020", # Boxing day
            "31/12/2020"], # New Year's Eve
    "2021": ["01/01/2021", # New Year's day
            "02/04/2021", # Good Friday
            "05/04/2021", # Easter Monday
            "01/05/2021", # Labor day
            "24/05/2021", # White Monday
            "03/10/2021", # Day of German Unity
            "24/12/2021", # Christmas eve
            "25/12/2021", # Christmas
            "26/12/2021", # Boxing day
            "31/12/2021"] # New Year's Eve
} # impacts GER30

US
# Out:
# {'2010': ['01/01/2010',
#   '18/01/2010',
#   '15/02/2010',
#   '02/04/2010',
#   '31/05/2010',
#   '05/07/2010',
#   '06/09/2010',
#   '25/11/2010',
#   '26/11/2010',
#   '24/12/2010'],
#  '2011': ['01/01/2011',
#   '17/01/2011',
#   '21/02/2011',
#   '22/04/2011',
#   '30/05/2011',
#   '04/07/2011',
#   '05/09/2011',
#   '24/11/2011',
#   '26/12/2011'],
#  '2012': ['01/01/2012',
#   '16/01/2012',
#   '20/02/2012',
#   '06/04/2012',
#   '28/05/2012',
#   '04/07/2012',
#   '03/09/2012',
#   '22/11/2012',
#   '25/12/2012'],
#  '2013': ['01/01/2013',
#   '21/01/2013',
#   '18/02/2013',
#   '29/03/2013',
#   '27/05/2013',
#   '04/07/2013',
#   '02/09/2013',
#   '28/11/2013',
#   '25/12/2013'],
#  '2014': ['01/01/2014',
#   '20/01/2014',
#   '17/02/2014',
#   '18/04/2014',
#   '26/05/2014',
#   '04/07/2014',
#   '01/09/2014',
#   '27/11/2014',
#   '25/12/2014'],
#  '2015': ['01/01/2015',
#   '19/01/2015',
#   '16/02/2015',
#   '03/04/2015',
#   '25/05/2015',
#   '03/07/2015',
# ...

# %%
df = pd.DataFrame(US)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 df = pd.DataFrame(US)
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:637, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     631     mgr = self._init_mgr(
#     632         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     633     )
#     635 elif isinstance(data, dict):
#     636     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 637     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     638 elif isinstance(data, ma.MaskedArray):
#     639     import numpy.ma.mrecords as mrecords
#
# ...

# %%
df = pd.read_csv("Dataset/SP500_combination_data_23022022.csv", index_col=0)
df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values(by='Date').reset_index(drop=True)
df = df[df['Date'] < pd.Timestamp(2020,1,1)]
df
# Out:
#            Date  SP500_Close  SP500_Open  SP500_High  SP500_Low  SP500_Volume  \
# 0    2010-01-01          NaN         NaN         NaN        NaN           NaN
# 1    2010-01-02          NaN         NaN         NaN        NaN           NaN
# 2    2010-01-03          NaN         NaN         NaN        NaN           NaN
# 3    2010-01-04      1132.99     1116.56     1133.87    1116.56           0.0
# 4    2010-01-05      1136.52     1132.66     1136.63    1129.66           0.0
# ...         ...          ...         ...         ...        ...           ...
# 3285 2019-12-26      3239.91     3227.20     3240.08    3227.20           0.0
# 3286 2019-12-27      3240.02     3247.23     3247.93    3234.37           0.0
# 3287 2019-12-29          NaN         NaN         NaN        NaN           NaN
# 3288 2019-12-30      3221.29     3240.09     3240.92    3216.57           0.0
# 3289 2019-12-31      3230.78     3215.18     3231.72    3212.03           0.0
#
# ...

# %%
def check_missing_dates(df, start_date, end_date):
    all_dates = []
    current_date = start_date
    while current_date <= end_date:
        if current_date.weekday() not in [5, 6]: # remove saturdays and sundays
            if not(current_date.day in [24, 25, 26, 31] and current_date.month == 12): # remove christmas and newyears
                if not(current_date.day in [1] and current_date.month == 1): # remove he first day of the year
                    all_dates.append(current_date)
        current_date = current_date + timedelta(days=1)

    print(f"The data should contain {len(all_dates)} observations")
    for index, row in df.iterrows():
        all_dates.remove(row['Date'])
    print(f"The data contains {len(df)} observations")
    print(f"The data is possibly missing {len(all_dates)} observations. Further holidays should be removed from all_days.")
    return all_dates

def check_nans_per_data(df):
    cols = df.columns.tolist()
    nans = []
    for col in cols:
        nans.append(df[col].isna().sum()) 
    return cols, nans

cols, nans = check_nans_per_data(df)
cols, nans
# Out:
# (['Date',
#   'SP500_Close',
#   'SP500_Open',
#   'SP500_High',
#   'SP500_Low',
#   'SP500_Volume',
#   'SP500_relative_change_perc_1',
#   'SP500_relative_change_perc_5',
#   'SP500_relative_change_perc_10',
#   'SP500_relative_change_perc_20',
#   'SP500_relative_change_perc_50',
#   'SP500_EMA5',
#   'SP500_EMA10',
#   'SP500_EMA20',
#   'SP500_EMA50',
#   'SP500_MA5',
#   'SP500_MA10',
#   'SP500_MA20',
#   'SP500_MA50',
#   'SP500_week_high_1',
#   'SP500_week_high_10',
#   'SP500_week_high_52',
#   'SP500_week_low_1',
#   'SP500_week_low_10',
#   'SP500_week_low_52',
#   'SP500_ATR5',
#   'SP500_ATR10',
#   'SP500_ATR20',
#   'SP500_ATR50',
#   'SP500_RSI_14',
#   'SP500_RSI_28',
#   'SP500_stochastic_K_5',
#   'SP500_stochastic_K_10',
#   'SP500_stochastic_K_20',
#   'SP500_stochastic_K_50',
#   'SP500_stochastic_D_5_5',
#   'SP500_stochastic_D_10_10',
#   'SP500_stochastic_D_20_20',
#   'SP500_stochastic_D_50_50',
#   'SP500_momentum_4',
#   'SP500_momentum_8',
# ...
