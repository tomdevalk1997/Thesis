# %%
sp500_dir_red_3 = ['SP500_AD_oscillator_t-1', 'SP500_stochastic_K_10_t-1', 'SP500_williams_R_10_t-1', 'SP500_stochastic_K_50_t-3', 'SP500_williams_R_20_t-1', 'SP500_stochastic_D_5_5_t-2', 'SP500_F_relative_change_perc_1_t-3', 'Gold_F_relative_change_perc_1_t-2']
sp500_dir_red_5 = ['SP500_AD_oscillator_t-1', 'Silver_F_relative_change_perc_1_t-4', 'SP500_stochastic_K_50_t-4', 'SP500_stochastic_K_10_t-1', 'SP500_williams_R_20_t-1', 'SP500_momentum_16_t-1', 'SP500_F_relative_change_perc_1_t-4', 'Gold_F_relative_change_perc_1_t-2', 'SP500_AD_oscillator_t-4', 'SP500_AD_oscillator_t-3', 'SP500_stochastic_K_5_t-4', 'Silver_F_relative_change_perc_1_t-5', 'SP500_stochastic_K_50_t-5', 'SP500_williams_R_50_t-3', 'Copper_F_relative_change_perc_1_t-4', 'SP500_stochastic_D_5_5_t-2', 'SP500_williams_R_50_t-4', 'SP500_F_relative_change_perc_1_t-3', 'SP500_stochastic_K_5_t-2', 'SP500_williams_R_5_t-5']
sp500_dir_red_10 = ['SP500_stochastic_K_50_t-5', 'SP500_williams_R_10_t-3', 'SP500_relative_change_perc_1_t-4', 'SP500_williams_R_50_t-3', 'Copper_F_relative_change_perc_1_t-7', 'SP500_stochastic_K_20_t-4', 'Gold_F_relative_change_perc_1_t-10', 'SP500_stochastic_K_5_t-4', 'SP500_momentum_16_t-7', 'SP500_stochastic_K_10_t-10', 'Silver_F_relative_change_perc_1_t-5', 'Gold_F_relative_change_perc_1_t-2', 'SP500_stochastic_K_50_t-4', 'SP500_williams_R_50_t-4', 'SP500_stochastic_K_10_t-1', 'SP500_stochastic_K_10_t-7', 'SP500_AD_oscillator_t-9', 'SP500_AD_oscillator_t-1', 'SP500_stochastic_K_5_t-2', 'Silver_F_relative_change_perc_1_t-10', 'SP500_stochastic_D_5_5_t-5', 'SP500_williams_R_10_t-7']
sp500_dir_red_20 = ['Silver_F_relative_change_perc_1_t-16', 'Copper_F_relative_change_perc_1_t-19', 'Gold_F_relative_change_perc_1_t-14', 'SP500_stochastic_K_50_t-13', 'Silver_F_relative_change_perc_1_t-5', 'SP500_AD_oscillator_t-6', 'SP500_F_relative_change_perc_1_t-13', 'SP500_AD_oscillator_t-17', 'Silver_F_relative_change_perc_1_t-8', 'SP500_stochastic_K_10_t-1', 'SP500_F_relative_change_perc_1_t-12', 'SP500_relative_change_perc_1_t-18', 'SP500_stochastic_K_5_t-6', 'SP500_stochastic_K_50_t-11', 'SP500_williams_R_5_t-5', 'SP500_williams_R_10_t-8', 'SP500_AD_oscillator_t-4', 'Copper_F_relative_change_perc_1_t-4', 'SP500_stochastic_K_10_t-10', 'SP500_williams_R_50_t-11', 'SP500_williams_R_50_t-4', 'SP500_momentum_8_t-20', 'SP500_momentum_8_t-4', 'SP500_stochastic_K_5_t-20', 'Silver_F_relative_change_perc_1_t-19', 'SP500_F_relative_change_perc_1_t-17', 'SP500_williams_R_5_t-18', 'SP500_F_relative_change_perc_1_t-10', 'SP500_momentum_8_t-14', 'Gold_F_relative_change_perc_1_t-10', 'SP500_stochastic_K_5_t-4', 'SP500_AD_oscillator_t-14', 'SP500_stochastic_K_50_t-4', 'Gold_F_relative_change_perc_1_t-8', 'SP500_stochastic_K_10_t-7', 'Silver_F_relative_change_perc_1_t-4', 'Silver_F_relative_change_perc_1_t-1', 'SP500_AD_oscillator_t-1', 'Copper_F_relative_change_perc_1_t-11', 'SP500_AD_oscillator_t-15', 'SP500_williams_R_10_t-11', 'SP500_stochastic_D_5_5_t-5', 'SP500_momentum_16_t-5', 'SP500_relative_change_perc_1_t-16', 'SP500_stochastic_K_50_t-5', 'SP500_stochastic_K_5_t-16', 'SP500_AD_MACD_12_26_t-8', 'SP500_momentum_16_t-7', 'Copper_F_relative_change_perc_1_t-6', 'SP500_stochastic_D_5_5_t-19', 'SP500_AD_oscillator_t-20', 'SP500_relative_change_perc_1_t-2', 'SP500_williams_R_50_t-14', 'SP500_stochastic_K_50_t-14', 'SP500_momentum_16_t-14', 'SP500_momentum_16_t-20', 'Gold_F_relative_change_perc_1_t-13', 'SP500_williams_R_5_t-6']

sp500_dir_com_3 = ['SP500_momentum_8_t-1', 'SP500_momentum_16_t-1', 'SP500_stochastic_K_10_t-1', 'SP500_AD_MACD_12_26_t-3', 'SP500_stochastic_K_50_t-3', 'Gold_F_relative_change_perc_1_t-2', 'SP500_williams_R_5_t-1', 'SP500_williams_R_10_t-2', 'SP500_stochastic_D_5_5_t-2', 'SP500_williams_R_20_t-1', 'SP500_relative_change_perc_1_t-3', 'SP500_williams_R_10_t-1', 'SP500_stochastic_D_5_5_t-1', 'SP500_AD_oscillator_t-1', 'SP500_stochastic_D_5_5_t-3', 'SP500_stochastic_K_5_t-3']
sp500_dir_com_5 = ['Silver_F_relative_change_perc_1_t-5', 'SP500_momentum_16_t-1', 'Silver_F_relative_change_perc_1_t-4', 'SP500_stochastic_K_5_t-2', 'SP500_stochastic_K_10_t-1', 'SP500_stochastic_K_5_t-4', 'Copper_F_relative_change_perc_1_t-4', 'SP500_williams_R_50_t-4', 'SP500_AD_oscillator_t-4', 'SP500_williams_R_50_t-3', 'SP500_AD_oscillator_t-3', 'SP500_stochastic_K_50_t-4', 'SP500_stochastic_K_50_t-5', 'SP500_relative_change_perc_1_t-4', 'SP500_williams_R_5_t-5', 'Gold_F_relative_change_perc_1_t-2', 'SP500_stochastic_D_5_5_t-2', 'SP500_williams_R_20_t-1', 'SP500_relative_change_perc_1_t-3', 'SP500_AD_oscillator_t-1']
sp500_dir_com_10 = ['Silver_F_relative_change_perc_1_t-5', 'Copper_F_relative_change_perc_1_t-7', 'SP500_stochastic_K_5_t-2', 'SP500_williams_R_10_t-3', 'SP500_stochastic_K_10_t-1', 'SP500_stochastic_D_5_5_t-5', 'SP500_AD_oscillator_t-9', 'SP500_stochastic_K_5_t-4', 'SP500_williams_R_50_t-4', 'SP500_williams_R_50_t-3', 'SP500_stochastic_K_50_t-4', 'SP500_stochastic_K_10_t-7', 'SP500_stochastic_K_50_t-5', 'SP500_stochastic_K_10_t-10', 'SP500_relative_change_perc_1_t-4', 'SP500_momentum_16_t-7', 'SP500_williams_R_10_t-7', 'Gold_F_relative_change_perc_1_t-2', 'SP500_stochastic_K_20_t-4', 'SP500_AD_oscillator_t-1', 'Gold_F_relative_change_perc_1_t-10', 'Silver_F_relative_change_perc_1_t-10']
sp500_dir_com_20 = ['SP500_stochastic_K_10_t-7', 'SP500_AD_oscillator_t-1', 'Gold_F_relative_change_perc_1_t-14', 'SP500_stochastic_K_10_t-1', 'SP500_williams_R_5_t-6', 'SP500_stochastic_D_5_5_t-5', 'SP500_momentum_16_t-5', 'SP500_williams_R_20_t-1', 'SP500_AD_oscillator_t-6', 'Silver_F_relative_change_perc_1_t-16', 'SP500_momentum_16_t-19', 'SP500_AD_oscillator_t-17', 'SP500_F_relative_change_perc_1_t-16', 'SP500_AD_oscillator_t-4', 'SP500_stochastic_K_5_t-4', 'Silver_F_relative_change_perc_1_t-8', 'Silver_F_relative_change_perc_1_t-5', 'SP500_stochastic_K_5_t-20', 'Copper_F_relative_change_perc_1_t-19', 'Copper_F_relative_change_perc_1_t-4', 'SP500_AD_oscillator_t-14', 'SP500_momentum_16_t-7', 'SP500_F_relative_change_perc_1_t-17', 'SP500_williams_R_50_t-11', 'Gold_F_relative_change_perc_1_t-13']

# %%
print("S&P500")
print("Lookback 3")
print(f"\tN Features Reduced: {len(sp500_dir_red_3)}")
print(f"\tN Features Combined: {len(sp500_dir_com_3)}")
diff = []
for i in sp500_dir_red_3:
    if i not in sp500_dir_com_3:
        diff.append(i)
print(f"\tFeatures in Reduced and not in Combined: {diff}")
diff = []
for i in sp500_dir_com_3:
    if i not in sp500_dir_red_3:
        diff.append(i)
print(f"\tFeatures in Combined and not in Reduced: {diff}")



print("\n")
print("Lookback 5")
print(f"\tN Features Reduced: {len(sp500_dir_red_5)}")
print(f"\tN Features Combined: {len(sp500_dir_com_5)}")
diff = []
for i in sp500_dir_red_5:
    if i not in sp500_dir_com_5:
        diff.append(i)
print(f"\tFeatures in Reduced and not in Combined: {diff}")
diff = []
for i in sp500_dir_com_5:
    if i not in sp500_dir_red_5:
        diff.append(i)
print(f"\tFeatures in Combined and not in Reduced: {diff}")


print("\n")
print("Lookback 10")
print(f"\tN Features Reduced: {len(sp500_dir_red_10)}")
print(f"\tN Features Combined: {len(sp500_dir_com_10)}")
diff = []
for i in sp500_dir_red_10:
    if i not in sp500_dir_com_10:
        diff.append(i)
print(f"\tFeatures in Reduced and not in Combined: {diff}")
diff = []
for i in sp500_dir_com_10:
    if i not in sp500_dir_red_10:
        diff.append(i)
print(f"\tFeatures in Combined and not in Reduced: {diff}")

print("\n")
print("Lookback 20")
print(f"\tN Features Reduced: {len(sp500_dir_red_20)}")
print(f"\tN Features Combined: {len(sp500_dir_com_20)}")
diff = []
for i in sp500_dir_red_20:
    if i not in sp500_dir_com_20:
        diff.append(i)
print(f"\tFeatures in Reduced and not in Combined: {diff}")
diff = []
for i in sp500_dir_com_20:
    if i not in sp500_dir_red_20:
        diff.append(i)
print(f"\tFeatures in Combined and not in Reduced: {diff}")
# Out:
# S&P500
# Lookback 3
# 	N Features Reduced: 8
# 	N Features Combined: 16
# 	Features in Reduced and not in Combined: ['SP500_F_relative_change_perc_1_t-3']
# 	Features in Combined and not in Reduced: ['SP500_momentum_8_t-1', 'SP500_momentum_16_t-1', 'SP500_AD_MACD_12_26_t-3', 'SP500_williams_R_5_t-1', 'SP500_williams_R_10_t-2', 'SP500_relative_change_perc_1_t-3', 'SP500_stochastic_D_5_5_t-1', 'SP500_stochastic_D_5_5_t-3', 'SP500_stochastic_K_5_t-3']
#
#
# Lookback 5
# 	N Features Reduced: 20
# 	N Features Combined: 20
# 	Features in Reduced and not in Combined: ['SP500_F_relative_change_perc_1_t-4', 'SP500_F_relative_change_perc_1_t-3']
# 	Features in Combined and not in Reduced: ['SP500_relative_change_perc_1_t-4', 'SP500_relative_change_perc_1_t-3']
#
#
# Lookback 10
# 	N Features Reduced: 22
# 	N Features Combined: 22
# 	Features in Reduced and not in Combined: []
# 	Features in Combined and not in Reduced: []
#
#
# Lookback 20
# 	N Features Reduced: 58
# 	N Features Combined: 25
# ...

# %%
us30_dir_red_3 = ['US30_williams_R_5_t-3', 'US30_stochastic_K_50_t-3', 'USDHKD_relative_change_perc_1_t-2', 'Gold_F_relative_change_perc_1_t-3', 'US30_stochastic_D_5_5_t-3', 'US30_williams_R_10_t-1', 'US30_momentum_4_t-3', 'US30_stochastic_D_5_5_t-2', 'Silver_F_relative_change_perc_1_t-1']
us30_dir_red_5 = ['US30_williams_R_5_t-5', 'US30_AD_oscillator_t-3', 'US30_stochastic_D_5_5_t-3', 'Copper_F_relative_change_perc_1_t-3', 'US30_relative_change_perc_1_t-1', 'Gold_F_relative_change_perc_1_t-1', 'US30_F_relative_change_perc_1_t-2', 'US30_momentum_4_t-3', 'US30_relative_change_perc_1_t-4', 'US30_williams_R_5_t-4', 'US30_stochastic_K_10_t-3', 'US30_momentum_16_t-4', 'US30_relative_change_perc_1_t-3', 'Silver_F_relative_change_perc_1_t-4', 'US30_stochastic_K_20_t-4', 'USDHKD_relative_change_perc_1_t-2', 'Gold_F_relative_change_perc_1_t-3', 'Silver_F_relative_change_perc_1_t-5', 'US30_momentum_4_t-1', 'Gold_F_relative_change_perc_1_t-5', 'Copper_F_relative_change_perc_1_t-1', 'USDHKD_relative_change_perc_1_t-4']
us30_dir_red_10 = ['US30_williams_R_50_t-9', 'US30_momentum_16_t-10', 'US30_williams_R_5_t-9', 'Copper_F_relative_change_perc_1_t-3', 'US30_AD_oscillator_t-6', 'USDHKD_relative_change_perc_1_t-10', 'US30_momentum_4_t-5', 'US30_relative_change_perc_1_t-4', 'Copper_F_relative_change_perc_1_t-7', 'US30_stochastic_D_5_5_t-9', 'Copper_F_relative_change_perc_1_t-1', 'Gold_F_relative_change_perc_1_t-6', 'Silver_F_relative_change_perc_1_t-6', 'US30_stochastic_K_20_t-4', 'Gold_F_relative_change_perc_1_t-7', 'Silver_F_relative_change_perc_1_t-5', 'US30_AD_oscillator_t-9', 'Silver_F_relative_change_perc_1_t-4']
us30_dir_red_20 = ['US30_williams_R_5_t-14', 'Copper_F_relative_change_perc_1_t-1', 'Silver_F_relative_change_perc_1_t-5', 'US30_stochastic_K_50_t-11', 'Copper_F_relative_change_perc_1_t-3', 'US30_stochastic_K_20_t-18', 'US30_momentum_16_t-10', 'Silver_F_relative_change_perc_1_t-4', 'US30_stochastic_D_5_5_t-9', 'US30_stochastic_D_5_5_t-15', 'Copper_F_relative_change_perc_1_t-15', 'US30_williams_R_5_t-9']

us30_dir_com_3 = ['USDCAD_relative_change_perc_5_t-2', 'USDCAD_relative_change_perc_10_t-3', 'Corn_F_relative_change_perc_5_t-2', 'SSE50_relative_change_perc_5_t-2', 'NaturalGas_F_Volume_t-2', 'USDCHF_relative_change_perc_20_t-2', 'HS50_relative_change_perc_50_t-3', 'UK100_relative_change_perc_1_t-2', 'NZDUSD_relative_change_perc_10_t-2', 'UK100_F_relative_change_perc_10_t-3', 'US30_momentum_4_t-3', 'US30_relative_change_perc_20_t-1', 'MSFT_relative_change_perc_1_t-1', 'HS50_relative_change_perc_5_t-3', 'BrentOil_F_relative_change_perc_1_t-3', 'USDJPY_relative_change_perc_5_t-2', 'NIKKEI225_F_relative_change_perc_20_t-2', 'MSFT_relative_change_perc_5_t-2', 'NIKKEI225_relative_change_perc_10_t-1', 'US30_OBV_t-2', 'USDJPY_relative_change_perc_1_t-1', 'NIKKEI225_relative_change_perc_5_t-1', 'GS_relative_change_perc_1_t-1', 'NIKKEI225_F_relative_change_perc_10_t-3']
us30_dir_com_5 = ['USDCAD_relative_change_perc_5_t-2', 'Corn_F_Volume_t-5', 'HS50_F_relative_change_perc_50_t-5', 'GER30_Volume_t-2', 'NaturalGas_F_Volume_t-2', 'UK100_F_Volume_t-3', 'SSE50_relative_change_perc_1_t-4', 'UNH_relative_change_perc_20_t-2', 'UNH_relative_change_perc_1_t-4', 'Copper_F_relative_change_perc_1_t-3', 'NASDAQ_F_relative_change_perc_10_t-3', 'US30_OBV_t-3', 'USDJPY_relative_change_perc_1_t-3', 'BrentOil_F_relative_change_perc_5_t-4', 'UK100_F_relative_change_perc_1_t-1', 'NZDUSD_relative_change_perc_20_t-1', 'GER30_F_Volume_t-1']
us30_dir_com_10 = ['US2000_F_relative_change_perc_20_t-5', 'HD_relative_change_perc_5_t-8', 'HD_relative_change_perc_20_t-6', 'NASDAQ_relative_change_perc_50_t-9', 'MSFT_relative_change_perc_1_t-1', 'MSFT_relative_change_perc_5_t-2', 'USDCHF_relative_change_perc_10_t-9', 'UK100_relative_change_perc_5_t-10', 'NIKKEI225_F_relative_change_perc_20_t-10', 'US2000_relative_change_perc_10_t-5', 'US30_williams_R_5_t-9']
us30_dir_com_20 = ['NaturalGas_F_relative_change_perc_5_t-13', 'UK100_F_relative_change_perc_1_t-1', 'HD_relative_change_perc_5_t-8', 'NIKKEI225_F_Volume_t-7', 'SSE50_F_relative_change_perc_10_t-9', 'HS50_F_relative_change_perc_50_t-5', 'UNH_relative_change_perc_1_t-4', 'GBPUSD_relative_change_perc_1_t-10', 'USDJPY_relative_change_perc_1_t-3', 'Silver_F_relative_change_perc_10_t-17', 'UK100_relative_change_perc_5_t-20', 'GBPUSD_relative_change_perc_5_t-14', 'MSFT_relative_change_perc_1_t-18', 'NaturalGas_F_Volume_t-2', 'SSE50_relative_change_perc_1_t-4', 'USDCHF_relative_change_perc_1_t-15', 'HD_relative_change_perc_20_t-6']

# %%
print("US30")
print("Lookback 3")
print(f"\tN Features Reduced: {len(us30_dir_red_3)}")
print(f"\tN Features Combined: {len(us30_dir_com_3)}")
diff = []
for i in us30_dir_red_3:
    if i not in us30_dir_com_3:
        diff.append(i)
print(f"\tFeatures in Reduced and not in Combined: {diff}")
diff = []
for i in us30_dir_com_3:
    if i not in us30_dir_red_3:
        diff.append(i)
print(f"\tFeatures in Combined and not in Reduced: {diff}")

print("\n")
print("Lookback 5")
print(f"\tN Features Reduced: {len(us30_dir_red_5)}")
print(f"\tN Features Combined: {len(us30_dir_com_5)}")
diff = []
for i in us30_dir_red_5:
    if i not in us30_dir_com_5:
        diff.append(i)
print(f"\tFeatures in Reduced and not in Combined: {diff}")
diff = []
for i in us30_dir_com_5:
    if i not in us30_dir_red_5:
        diff.append(i)
print(f"\tFeatures in Combined and not in Reduced: {diff}")


print("\n")
print("Lookback 10")
print(f"\tN Features Reduced: {len(us30_dir_red_10)}")
print(f"\tN Features Combined: {len(us30_dir_com_10)}")
diff = []
for i in us30_dir_red_10:
    if i not in us30_dir_com_10:
        diff.append(i)
print(f"\tFeatures in Reduced and not in Combined: {diff}")
diff = []
for i in us30_dir_com_10:
    if i not in us30_dir_red_10:
        diff.append(i)
print(f"\tFeatures in Combined and not in Reduced: {diff}")

print("\n")
print("Lookback 20")
print(f"\tN Features Reduced: {len(us30_dir_red_20)}")
print(f"\tN Features Combined: {len(us30_dir_com_20)}")
diff = []
for i in us30_dir_red_20:
    if i not in us30_dir_com_20:
        diff.append(i)
print(f"\tFeatures in Reduced and not in Combined: {diff}")
diff = []
for i in us30_dir_com_20:
    if i not in us30_dir_red_20:
        diff.append(i)
print(f"\tFeatures in Combined and not in Reduced: {diff}")
# Out:
# US30
# Lookback 3
# 	N Features Reduced: 9
# 	N Features Combined: 24
# 	Features in Reduced and not in Combined: ['US30_williams_R_5_t-3', 'US30_stochastic_K_50_t-3', 'USDHKD_relative_change_perc_1_t-2', 'Gold_F_relative_change_perc_1_t-3', 'US30_stochastic_D_5_5_t-3', 'US30_williams_R_10_t-1', 'US30_stochastic_D_5_5_t-2', 'Silver_F_relative_change_perc_1_t-1']
# ...

# %%
NASDAQ Direction
Reduced
  3             ['NASDAQ_momentum_4_t-2', 'Copper_F_relative_change_perc_1_t-3', 'NASDAQ_momentum_4_t-3', 'NASDAQ_momentum_8_t-2', 'NASDAQ_williams_R_20_t-3', 'NASDAQ_momentum_8_t-1', 'NASDAQ_stochastic_K_10_t-1', 'USDHKD_relative_change_perc_1_t-3', 'NASDAQ_AD_oscillator_t-1', 'NASDAQ_williams_R_5_t-2', 'NASDAQ_williams_R_50_t-2', 'Silver_F_relative_change_perc_1_t-1', 'USDHKD_relative_change_perc_1_t-2', 'NASDAQ_AD_oscillator_t-3', 'NASDAQ_stochastic_K_20_t-3', 'Gold_F_relative_change_perc_1_t-1']
  5             ['Copper_F_relative_change_perc_1_t-4', 'Copper_F_relative_change_perc_1_t-3', 'Silver_F_relative_change_perc_1_t-4', 'Silver_F_relative_change_perc_1_t-2', 'NASDAQ_AD_oscillator_t-1', 'Silver_F_relative_change_perc_1_t-1', 'Silver_F_relative_change_perc_1_t-5', 'NASDAQ_momentum_8_t-3', 'Copper_F_relative_change_perc_1_t-2']
  10            ['NASDAQ_AD_oscillator_t-3', 'NASDAQ_williams_R_20_t-10', 'Copper_F_relative_change_perc_1_t-3', 'NASDAQ_momentum_8_t-2', 'Copper_F_relative_change_perc_1_t-10', 'NASDAQ_williams_R_10_t-9', 'NASDAQ_relative_change_perc_1_t-8', 'NASDAQ_stochastic_D_5_5_t-5', 'NASDAQ_momentum_8_t-3', 'NASDAQ_williams_R_50_t-7', 'NASDAQ_AD_oscillator_t-8', 'NASDAQ_williams_R_50_t-1', 'Copper_F_relative_change_perc_1_t-4']
  20            ['NASDAQ_AD_oscillator_t-11', 'Silver_F_relative_change_perc_1_t-15', 'NASDAQ_AD_oscillator_t-4', 'NASDAQ_stochastic_K_20_t-20', 'NASDAQ_F_relative_change_perc_1_t-17', 'NASDAQ_momentum_8_t-3', 'Silver_F_relative_change_perc_1_t-14', 'NASDAQ_AD_oscillator_t-8', 'Copper_F_relative_change_perc_1_t-4', 'Copper_F_relative_change_perc_1_t-3', 'NASDAQ_stochastic_K_10_t-16', 'NASDAQ_momentum_4_t-2', 'Copper_F_relative_change_perc_1_t-20', 'Silver_F_relative_change_perc_1_t-1', 'NASDAQ_momentum_8_t-13']
  Combined
  3             ['WTIOil_F_relative_change_perc_5_t-2', 'MSFT_relative_change_perc_5_t-2', 'CAC40_F_Volume_t-2', 'Copper_F_relative_change_perc_1_t-3', 'NIKKEI225_F_relative_change_perc_20_t-1', 'NASDAQ_momentum_8_t-2', 'USDJPY_relative_change_perc_1_t-1', 'NASDAQ_F_relative_change_perc_50_t-1', 'NaturalGas_F_relative_change_perc_20_t-3', 'NIKKEI225_relative_change_perc_50_t-3', 'SSE50_F_relative_change_perc_20_t-1', 'HS50_relative_change_perc_5_t-1', 'USDCHF_relative_change_perc_1_t-2']
  5             ['HS50_F_relative_change_perc_1_t-1', 'NASDAQ_F_relative_change_perc_1_t-4', 'NaturalGas_F_Volume_t-2', 'AUDUSD_relative_change_perc_1_t-4', 'WTIOil_F_relative_change_perc_5_t-2', 'Copper_F_relative_change_perc_1_t-4', 'NaturalGas_F_relative_change_perc_1_t-5', 'WTIOil_F_Volume_t-1', 'NIKKEI225_relative_change_perc_20_t-3', 'Corn_F_relative_change_perc_5_t-3', 'GER30_relative_change_perc_50_t-4', 'NZDUSD_relative_change_perc_20_t-5', 'AMZN_relative_change_perc_5_t-5', 'UK100_relative_change_perc_50_t-1']
  10            ['NaturalGas_F_Volume_t-2', 'CAC40_relative_change_perc_10_t-10', 'AUDUSD_relative_change_perc_10_t-7', 'US30_relative_change_perc_20_t-3', 'NIKKEI225_relative_change_perc_50_t-7', 'UK100_F_Volume_t-2', 'NaturalGas_F_relative_change_perc_5_t-4', 'MSFT_Volume_t-10', 'NASDAQ_relative_change_perc_1_t-7', 'Gold_F_Volume_t-5', 'US30_F_relative_change_perc_5_t-6', 'NaturalGas_F_relative_change_perc_1_t-4', 'CAC40_F_relative_change_perc_1_t-9', 'BrentOil_F_relative_change_perc_10_t-6', 'Corn_F_relative_change_perc_1_t-9', 'NASDAQ_relative_change_perc_50_t-1', 'NaturalGas_F_relative_change_perc_1_t-5', 'NASDAQ_F_Volume_t-9', 'Copper_F_relative_change_perc_50_t-10', 'UK100_F_relative_change_perc_20_t-1', 'Gold_F_Volume_t-1', 'NIKKEI225_F_relative_change_perc_20_t-1', 'NZDUSD_relative_change_perc_10_t-6', 'CAC40_Volume_t-10', 'AAPL_relative_change_perc_50_t-8', 'NaturalGas_F_relative_change_perc_20_t-3', 'NZDUSD_relative_change_perc_20_t-5', 'NASDAQ_bollinger_low_5_t-6']
  20            ['USDCHF_relative_change_perc_10_t-16', 'Corn_F_relative_change_perc_10_t-14', 'USDCHF_relative_change_perc_5_t-4', 'MSFT_Volume_t-10', 'GER30_F_Volume_t-10', 'Corn_F_relative_change_perc_10_t-20', 'WTIOil_F_relative_change_perc_5_t-11', 'NASDAQ_AD_oscillator_t-8', 'Copper_F_relative_change_perc_1_t-4', 'GBPUSD_relative_change_perc_5_t-14', 'US30_F_relative_change_perc_5_t-19', 'NASDAQ_williams_R_5_t-16', 'AUDUSD_relative_change_perc_1_t-14', 'AMZN_Volume_t-11', 'NASDAQ_bollinger_high_5_t-2', 'NIKKEI225_relative_change_perc_1_t-16', 'NIKKEI225_F_relative_change_perc_10_t-11']


US30 Direction
Reduced
  3             ['US30_williams_R_5_t-3', 'US30_stochastic_K_50_t-3', 'USDHKD_relative_change_perc_1_t-2', 'Gold_F_relative_change_perc_1_t-3', 'US30_stochastic_D_5_5_t-3', 'US30_williams_R_10_t-1', 'US30_momentum_4_t-3', 'US30_stochastic_D_5_5_t-2', 'Silver_F_relative_change_perc_1_t-1']
  5             ['US30_williams_R_5_t-5', 'US30_AD_oscillator_t-3', 'US30_stochastic_D_5_5_t-3', 'Copper_F_relative_change_perc_1_t-3', 'US30_relative_change_perc_1_t-1', 'Gold_F_relative_change_perc_1_t-1', 'US30_F_relative_change_perc_1_t-2', 'US30_momentum_4_t-3', 'US30_relative_change_perc_1_t-4', 'US30_williams_R_5_t-4', 'US30_stochastic_K_10_t-3', 'US30_momentum_16_t-4', 'US30_relative_change_perc_1_t-3', 'Silver_F_relative_change_perc_1_t-4', 'US30_stochastic_K_20_t-4', 'USDHKD_relative_change_perc_1_t-2', 'Gold_F_relative_change_perc_1_t-3', 'Silver_F_relative_change_perc_1_t-5', 'US30_momentum_4_t-1', 'Gold_F_relative_change_perc_1_t-5', 'Copper_F_relative_change_perc_1_t-1', 'USDHKD_relative_change_perc_1_t-4']
  10            ['US30_williams_R_50_t-9', 'US30_momentum_16_t-10', 'US30_williams_R_5_t-9', 'Copper_F_relative_change_perc_1_t-3', 'US30_AD_oscillator_t-6', 'USDHKD_relative_change_perc_1_t-10', 'US30_momentum_4_t-5', 'US30_relative_change_perc_1_t-4', 'Copper_F_relative_change_perc_1_t-7', 'US30_stochastic_D_5_5_t-9', 'Copper_F_relative_change_perc_1_t-1', 'Gold_F_relative_change_perc_1_t-6', 'Silver_F_relative_change_perc_1_t-6', 'US30_stochastic_K_20_t-4', 'Gold_F_relative_change_perc_1_t-7', 'Silver_F_relative_change_perc_1_t-5', 'US30_AD_oscillator_t-9', 'Silver_F_relative_change_perc_1_t-4']
  20            ['US30_williams_R_5_t-14', 'Copper_F_relative_change_perc_1_t-1', 'Silver_F_relative_change_perc_1_t-5', 'US30_stochastic_K_50_t-11', 'Copper_F_relative_change_perc_1_t-3', 'US30_stochastic_K_20_t-18', 'US30_momentum_16_t-10', 'Silver_F_relative_change_perc_1_t-4', 'US30_stochastic_D_5_5_t-9', 'US30_stochastic_D_5_5_t-15', 'Copper_F_relative_change_perc_1_t-15', 'US30_williams_R_5_t-9']
Combined
  3             ['USDCAD_relative_change_perc_5_t-2', 'USDCAD_relative_change_perc_10_t-3', 'Corn_F_relative_change_perc_5_t-2', 'SSE50_relative_change_perc_5_t-2', 'NaturalGas_F_Volume_t-2', 'USDCHF_relative_change_perc_20_t-2', 'HS50_relative_change_perc_50_t-3', 'UK100_relative_change_perc_1_t-2', 'NZDUSD_relative_change_perc_10_t-2', 'UK100_F_relative_change_perc_10_t-3', 'US30_momentum_4_t-3', 'US30_relative_change_perc_20_t-1', 'MSFT_relative_change_perc_1_t-1', 'HS50_relative_change_perc_5_t-3', 'BrentOil_F_relative_change_perc_1_t-3', 'USDJPY_relative_change_perc_5_t-2', 'NIKKEI225_F_relative_change_perc_20_t-2', 'MSFT_relative_change_perc_5_t-2', 'NIKKEI225_relative_change_perc_10_t-1', 'US30_OBV_t-2', 'USDJPY_relative_change_perc_1_t-1', 'NIKKEI225_relative_change_perc_5_t-1', 'GS_relative_change_perc_1_t-1', 'NIKKEI225_F_relative_change_perc_10_t-3']
  5             ['USDCAD_relative_change_perc_5_t-2', 'Corn_F_Volume_t-5', 'HS50_F_relative_change_perc_50_t-5', 'GER30_Volume_t-2', 'NaturalGas_F_Volume_t-2', 'UK100_F_Volume_t-3', 'SSE50_relative_change_perc_1_t-4', 'UNH_relative_change_perc_20_t-2', 'UNH_relative_change_perc_1_t-4', 'Copper_F_relative_change_perc_1_t-3', 'NASDAQ_F_relative_change_perc_10_t-3', 'US30_OBV_t-3', 'USDJPY_relative_change_perc_1_t-3', 'BrentOil_F_relative_change_perc_5_t-4', 'UK100_F_relative_change_perc_1_t-1', 'NZDUSD_relative_change_perc_20_t-1', 'GER30_F_Volume_t-1']
  10            ['US2000_F_relative_change_perc_20_t-5', 'HD_relative_change_perc_5_t-8', 'HD_relative_change_perc_20_t-6', 'NASDAQ_relative_change_perc_50_t-9', 'MSFT_relative_change_perc_1_t-1', 'MSFT_relative_change_perc_5_t-2', 'USDCHF_relative_change_perc_10_t-9', 'UK100_relative_change_perc_5_t-10', 'NIKKEI225_F_relative_change_perc_20_t-10', 'US2000_relative_change_perc_10_t-5', 'US30_williams_R_5_t-9']
  20            ['NaturalGas_F_relative_change_perc_5_t-13', 'UK100_F_relative_change_perc_1_t-1', 'HD_relative_change_perc_5_t-8', 'NIKKEI225_F_Volume_t-7', 'SSE50_F_relative_change_perc_10_t-9', 'HS50_F_relative_change_perc_50_t-5', 'UNH_relative_change_perc_1_t-4', 'GBPUSD_relative_change_perc_1_t-10', 'USDJPY_relative_change_perc_1_t-3', 'Silver_F_relative_change_perc_10_t-17', 'UK100_relative_change_perc_5_t-20', 'GBPUSD_relative_change_perc_5_t-14', 'MSFT_relative_change_perc_1_t-18', 'NaturalGas_F_Volume_t-2', 'SSE50_relative_change_perc_1_t-4', 'USDCHF_relative_change_perc_1_t-15', 'HD_relative_change_perc_20_t-6']



SP500 Magnitude
Reduced
  3           ['Silver_F_relative_change_perc_1_t-3', 'SP500_stochastic_K_20_t-1', 'Silver_F_relative_change_perc_1_t-1', 'Copper_F_relative_change_perc_1_t-1', 'SP500_stochastic_K_50_t-1', 'Silver_F_relative_change_perc_1_t-2']
  5           ['SP500_momentum_16_t-5', 'SP500_AD_oscillator_t-4', 'SP500_stochastic_K_10_t-1', 'SP500_F_relative_change_perc_1_t-4', 'SP500_stochastic_K_20_t-1', 'Copper_F_relative_change_perc_1_t-4', 'Silver_F_relative_change_perc_1_t-4', 'Copper_F_relative_change_perc_1_t-1', 'SP500_AD_oscillator_t-1', 'SP500_stochastic_K_50_t-1', 'Silver_F_relative_change_perc_1_t-2']
  10          ['SP500_momentum_16_t-5', 'SP500_momentum_8_t-1', 'Silver_F_relative_change_perc_1_t-6', 'SP500_stochastic_K_10_t-1', 'SP500_relative_change_perc_1_t-4', 'SP500_F_relative_change_perc_1_t-4', 'SP500_stochastic_K_20_t-1', 'Copper_F_relative_change_perc_1_t-4', 'Silver_F_relative_change_perc_1_t-4', 'Copper_F_relative_change_perc_1_t-1', 'SP500_AD_oscillator_t-1', 'SP500_stochastic_K_50_t-1', 'Silver_F_relative_change_perc_1_t-2']
  20          ['SP500_stochastic_K_10_t-7', 'SP500_AD_oscillator_t-1', 'Gold_F_relative_change_perc_1_t-14', 'SP500_stochastic_K_10_t-1', 'SP500_williams_R_5_t-6', 'SP500_stochastic_D_5_5_t-5', 'SP500_momentum_16_t-5', 'SP500_williams_R_20_t-1', 'SP500_AD_oscillator_t-6', 'Silver_F_relative_change_perc_1_t-16', 'SP500_momentum_16_t-19', 'SP500_AD_oscillator_t-17', 'SP500_F_relative_change_perc_1_t-16', 'SP500_AD_oscillator_t-4', 'SP500_stochastic_K_5_t-4', 'Silver_F_relative_change_perc_1_t-8', 'Silver_F_relative_change_perc_1_t-5', 'SP500_stochastic_K_5_t-20', 'Copper_F_relative_change_perc_1_t-19', 'Copper_F_relative_change_perc_1_t-4', 'SP500_AD_oscillator_t-14', 'SP500_momentum_16_t-7', 'SP500_F_relative_change_perc_1_t-17', 'SP500_williams_R_50_t-11', 'Gold_F_relative_change_perc_1_t-13']
  Combined
  3           ['Silver_F_relative_change_perc_1_t-3', 'SP500_stochastic_K_20_t-1', 'Silver_F_relative_change_perc_1_t-1', 'Copper_F_relative_change_perc_1_t-1', 'SP500_stochastic_K_50_t-1', 'Silver_F_relative_change_perc_1_t-2']
  5           ['SP500_momentum_16_t-5', 'SP500_AD_oscillator_t-4', 'SP500_stochastic_K_10_t-1', 'SP500_F_relative_change_perc_1_t-4', 'SP500_stochastic_K_20_t-1', 'Copper_F_relative_change_perc_1_t-4', 'Silver_F_relative_change_perc_1_t-4', 'Copper_F_relative_change_perc_1_t-1', 'SP500_AD_oscillator_t-1', 'SP500_stochastic_K_50_t-1', 'Silver_F_relative_change_perc_1_t-2']
  10          ['SP500_momentum_16_t-5', 'SP500_momentum_8_t-1', 'Silver_F_relative_change_perc_1_t-6', 'SP500_stochastic_K_10_t-1', 'SP500_relative_change_perc_1_t-4', 'SP500_F_relative_change_perc_1_t-4', 'SP500_stochastic_K_20_t-1', 'Copper_F_relative_change_perc_1_t-4', 'Silver_F_relative_change_perc_1_t-4', 'Copper_F_relative_change_perc_1_t-1', 'SP500_AD_oscillator_t-1', 'SP500_stochastic_K_50_t-1', 'Silver_F_relative_change_perc_1_t-2']
  20          ['SP500_momentum_8_t-4', 'Silver_F_relative_change_perc_1_t-3', 'SP500_F_relative_change_perc_1_t-19', 'Silver_F_relative_change_perc_1_t-15', 'SP500_williams_R_50_t-10', 'SP500_williams_R_50_t-19', 'SP500_AD_oscillator_t-16', 'SP500_F_relative_change_perc_1_t-4', 'SP500_F_relative_change_perc_1_t-2', 'SP500_momentum_8_t-16', 'SP500_relative_change_perc_1_t-17', 'SP500_stochastic_K_20_t-18', 'SP500_relative_change_perc_1_t-16', 'SP500_F_relative_change_perc_1_t-8', 'Copper_F_relative_change_perc_1_t-1', 'SP500_relative_change_perc_1_t-10', 'SP500_stochastic_K_50_t-1', 'SP500_williams_R_20_t-14', 'SP500_momentum_8_t-1', 'SP500_stochastic_K_10_t-1', 'Copper_F_relative_change_perc_1_t-20', 'Copper_F_relative_change_perc_1_t-8', 'SP500_williams_R_50_t-16', 'SP500_williams_R_10_t-13', 'SP500_AD_oscillator_t-19', 'SP500_momentum_16_t-19', 'SP500_stochastic_K_20_t-1', 'SP500_AD_oscillator_t-9', 'SP500_AD_oscillator_t-1', 'Silver_F_relative_change_perc_1_t-2']
